# %% [markdown]
# <a href="https://colab.research.google.com/github/SvanaBirgis/Reiknifraedi/blob/main/VV3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##VV3. Fall Rosenbrocks
#
# Í æfingu í kafla A3 er „Fall Rosenbrocks“ skilgreint og sýnd mynd af því. Fallið er:
#
# $𝑓(𝑥,𝑦)=(1−𝑥)^2+100(𝑦−𝑥^2)^2$

# %% [markdown]
# a. Skrifið fall `rosen(x,y)` til að reikna gildi fallsins. Prófið að reikna 𝑓(−1.2,1) sem ætti að gefa 24.2.</li>

# %%
#a

def rosen(x,y):
  a = ((1-x)**2 + 100*(y-x**2)**2)
  return a

print(f'{rosen(-1.2,1):.1f}')
# Out:
# 24.2

# %% [markdown]
# b. Teiknið hæðarlínumynd af Rosenbrock-fallinu með `plt.contour` á svæðinu [−2,2]×[−1,3]. Látið hæðarlínurnar vera dökkbláar, merkið þær líkt og gert er í sýnidæminu Hæðarlínur falls í kafla A1, og hafið netlínur (grid) með. Til að fá góða mynd þarf bæði að reikna fallið á þéttu neti (t.d. 300×300) og velja hæðarlínugildin, sem fást með stikanum `levels` vel. Gildin 0.2,22,62,102,…,462 gefa t.d. ágæta mynd. Þau má búa til með: `levels = np.append([0.2], np.arange(2,50,4)**2)`

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-2,2,300)
y = np.linspace(-1,3,300)
(X,Y) = np.meshgrid(x,y)
Z = rosen(X,Y)

levels = np.append([0.2], np.arange(2,50,4)**2)
c = plt.contour(X,Y,Z,levels,colors='darkblue')
plt.clabel(c,fmt='%.0f')
plt.grid()
plt.show()
